# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# There are no missing values so now we just have to decide which datasets are useful for our model, keep them ,transform the ones that contain categorical values and drop the non-useful datasets.We will logically choose Price as an output.

# %%
df["condition"].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
df=df.drop(columns=["id","date","zipcode"],axis=1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 17 , 15 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %% [markdown]
# The strongest correlation that Price has is the one with the surface of the living("sqft living" = 0.7).It is also well correlated with : the "Grade" given to the construction (0.67), the surface of the surface above ground floor("sqft above"=0.61) and the square footage of interior living space for the nearest 15 neighbours ("sqft living15"=0.59).
# We note also a a relatively moderate correlation with the number of "bathrooms" (0.53).All of the other features do not have a big influence on the house pricings . So, we should drop them.

# %%
df=df.drop(columns=["sqft_lot15","long","lat","yr_renovated","yr_built","condition","waterfront","floors",
                   "sqft_lot","bedrooms","view"],axis=1)
df.head()
# Out:
#       price  bathrooms  sqft_living  grade  sqft_above  sqft_basement  \
# 0  221900.0       1.00         1180      7        1180              0
# 1  538000.0       2.25         2570      7        2170            400
# 2  180000.0       1.00          770      6         770              0
# 3  604000.0       3.00         1960      7        1050            910
# 4  510000.0       2.00         1680      8        1680              0
#
#    sqft_living15
# 0           1340
# 1           1690
# 2           2720
# 3           1360
# 4           1800

# %%
df.describe()
# Out:
#               price     bathrooms   sqft_living         grade    sqft_above  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.400881e+05      2.114757   2079.899736      7.656873   1788.390691
# std    3.671272e+05      0.770163    918.440897      1.175459    828.090978
# min    7.500000e+04      0.000000    290.000000      1.000000    290.000000
# 25%    3.219500e+05      1.750000   1427.000000      7.000000   1190.000000
# 50%    4.500000e+05      2.250000   1910.000000      7.000000   1560.000000
# 75%    6.450000e+05      2.500000   2550.000000      8.000000   2210.000000
# max    7.700000e+06      8.000000  13540.000000     13.000000   9410.000000
#
#        sqft_basement  sqft_living15
# count   21613.000000   21613.000000
# mean      291.509045    1986.552492
# std       442.575043     685.391304
# min         0.000000     399.000000
# 25%         0.000000    1490.000000
# 50%         0.000000    1840.000000
# ...

# %%
sns.regplot(x=df["sqft_living"], y=df["price"], fit_reg=False)

# %%
sns.distplot(df["price"],bins=90,hist=True,kde=True,color="green")

# %%
df.head()
# Out:
#       price  bathrooms  sqft_living  grade  sqft_above  sqft_basement  \
# 0  221900.0       1.00         1180      7        1180              0
# 1  538000.0       2.25         2570      7        2170            400
# 2  180000.0       1.00          770      6         770              0
# 3  604000.0       3.00         1960      7        1050            910
# 4  510000.0       2.00         1680      8        1680              0
#
#    sqft_living15
# 0           1340
# 1           1690
# 2           2720
# 3           1360
# 4           1800

# %%
from sklearn.preprocessing import StandardScaler
S=StandardScaler()
df1=df.copy()
df1=S.fit_transform(df1)
box_plot=sns.boxplot(data=df1)
box_plot.set(xlabel=["Price","Bathrooms","sqft_living","Grade","sqft_above","sqft_living15"])
# Out:
# [Text(0.5, 0, "['Price', 'Bathrooms', 'sqft_living', 'Grade', 'sqft_above', 'sqft_living15']")]

# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics
x= df["sqft_living"].values[:,np.newaxis]
y= df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  
lg=LinearRegression()
lg.fit(x_train, y_train)
predicted=lg.predict(x_test)

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("Square Footage of Living")
plt.xlabel("Price")
plt.plot(x_train,lg.predict(x_train)) #testing our model’s performance,color="k")
plt.show()

# %%
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %% [markdown]
# => Linear regression isn't the best model to express the relation between the price and the sqft_living since the MSE is too high and the R squared is too small.

# %%
x= df[["sqft_living","grade","sqft_above","sqft_living15","sqft_basement","bathrooms"]]
y= df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  
lg=LinearRegression()
lg.fit(x_train, y_train)
predicted=lg.predict(x_test)

# %%
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 56262505729.60911
# R squared 0.5524688924202672

# %% [markdown]
# => even though the Multilinear regression's MSE is lower than the Linear model's one, and the R squared is bigger than the one obtained with the Linear regression model.
# Multilinear regression can't be used to predict the houses price.

# %%
poly = PolynomialFeatures(degree =2) 
x= df[["sqft_living","grade","sqft_above","sqft_living15","bathrooms"]]
y= df["price"].values
x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  48805308317.63612
# R squared:  0.6117859771100211

# %%
x= df["sqft_living"].values.reshape(-1,1)
y= df["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="g")
plt.title("Linear regression")
plt.ylabel("Price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="r")

# %% [markdown]
# The polynomial regression is the best model to choose for this dataset among the models that we've seen through our course since it has a quite important R squared compared to other models (0.66) and a smaller MSE so less predictive errors.
